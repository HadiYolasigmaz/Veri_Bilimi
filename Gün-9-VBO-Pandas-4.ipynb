# %%
## artık elimizde 2 kütüphane var olacak numpy ve pandas
import numpy as np 
import pandas as pd

 
df = pd.DataFrame([['a', 'b'], ['c', 'd']], 
                  index =['row 1', 'row 2'], 
                  columns =['col 1', 'col 2']) 
  
print(df.to_json(orient ='split')) 
  
print(df.to_json(orient ='index'))
# Out:
# {"columns":["col 1","col 2"],"index":["row 1","row 2"],"data":[["a","b"],["c","d"]]}
# {"row 1":{"col 1":"a","col 2":"b"},"row 2":{"col 1":"c","col 2":"d"}}

# %%
df
# Out:
#       col 1 col 2
# row 1     a     b
# row 2     c     d

# %%
df=pd.read_csv("netflix_titles_nov_2019.csv")

# %%
df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %%
df.describe()
# Out:
#             show_id  release_year
# count  5.837000e+03   5837.000000
# mean   7.730079e+07   2013.688539
# std    9.479777e+06      8.419088
# min    2.698800e+05   1925.000000
# 25%    8.004520e+07   2013.000000
# 50%    8.016353e+07   2016.000000
# 75%    8.024188e+07   2018.000000
# max    8.122720e+07   2020.000000

# %%
df["release_year"]==2020
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5832    False
# 5833    False
# 5834    False
# 5835    False
# 5836    False
# Name: release_year, Length: 5837, dtype: bool

# %%
df[     df["release_year"]==2020     ]
# Out:
#       show_id               title director                    cast  \
# 133  81034946  Maradona in Mexico      NaN  Diego Armando Maradona
#
#                               country         date_added  release_year rating  \
# 133  Argentina, United States, Mexico  November 13, 2019          2020  TV-MA
#
#      duration                              listed_in  \
# 133  1 Season  Docuseries, Spanish-Language TV Shows
#
#                                            description     type
# 133  In this docuseries, soccer great Diego Maradon...  TV Show

# %%
df[df["release_year"]==2019]
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 2120  80209379          Tidying Up with Marie Kondo
# 2321  80229852                       Little Singham
# 2518  80202352                             Incoming
# 3263  80025384            Unbreakable Kimmy Schmidt
# 3264  70140358                 Arrested Development
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 2120                         NaN
# 2321                         NaN
# ...

# %%
df[df["country"]=="Turkey"]
# Out:
#        show_id                  title        director  \
# 128   81086462               The Yard             NaN
# 318   81132444          Consequences     Ozan Açıktan
# 359   81132442  Love, Surreal and Odd  Yılmaz Erdoğan
# 385   80176234       Black Money Love  Ahmet Katıksız
# 394   81132441     Bygones Be Bygones     Hakan Algül
# ...        ...                    ...             ...
# 5165  80126875                  Şubat             NaN
# 5166  80126991             Yunus Emre             NaN
# 5231  80037129                   Ezel             NaN
# 5232  80037176                  Kaçak             NaN
# 5233  80037484      Kurt Seyit & Sura             NaN
#
#                                                    cast country  \
# 128   Demet Evgar, Ceren Moray, Nursel Köse, Kenan E...  Turkey
# 318   Nehir Erdoğan, Tardu Flordun, İlker Kaleli, Se...  Turkey
# 359   Aylin Kontante, Bülent Emrah Parlak, Büşra Pek...  Turkey
# ...

# %%
df[     (df["country"]=="Turkey")      &           (df["type"]=="Movie")              ]
# Out:
#        show_id                              title  \
# 318   81132444                      Consequences
# 359   81132442              Love, Surreal and Odd
# 394   81132441                 Bygones Be Bygones
# 419   81158574                    Brother in Love
# 422   81132440                  Kids on the Block
# 522   81132443                           Deliha 2
# 567   81132439                     Travel Mates 2
# 603   81132438                      Locked on You
# 1424  81076251                         Money Trap
# 1473  81043542                Dabbe 6: The Return
# 1502  81043540                Dabbe 5: Zehr-i Cin
# 1503  81043541              Dabbe: The Possession
# 1841  81043345                       Among Family
# 1853  81043346                    My Travel Buddy
# 1866  81043343            You're Everything To Me
# 3370  80231066                     Babam ve Oğlum
# 3439  80231064              Ali Baba ve 7 Cüceler
# 3440  80227118              Aşk Tesadüfleri Sever
# ...

# %%
df_yeni  =   df[(df["country"]=="Turkey") & (df["type"]=="Movie")]

# %%
df_yeni
# Out:
#        show_id                              title  \
# 318   81132444                      Consequences
# 359   81132442              Love, Surreal and Odd
# 394   81132441                 Bygones Be Bygones
# 419   81158574                    Brother in Love
# 422   81132440                  Kids on the Block
# 522   81132443                           Deliha 2
# 567   81132439                     Travel Mates 2
# 603   81132438                      Locked on You
# 1424  81076251                         Money Trap
# 1473  81043542                Dabbe 6: The Return
# 1502  81043540                Dabbe 5: Zehr-i Cin
# 1503  81043541              Dabbe: The Possession
# 1841  81043345                       Among Family
# 1853  81043346                    My Travel Buddy
# 1866  81043343            You're Everything To Me
# 3370  80231066                     Babam ve Oğlum
# 3439  80231064              Ali Baba ve 7 Cüceler
# 3440  80227118              Aşk Tesadüfleri Sever
# ...

# %%
 df_yeni['duration'].min()
# Out:
# '100 min'

# %%
 df_yeni['duration'].max()
# Out:
# '99 min'

# %%
df_yeni['Dakika'], df_yeni['min'] =       df_yeni['duration'].str.split(' ', 1).str
# Out:
# /Users/hadi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_yeni['Dakika'].head(3)
# Out:
# 318    106
# 359     95
# 394    104
# Name: Dakika, dtype: object

# %%
df_yeni
# Out:
#        show_id                              title  \
# 318   81132444                      Consequences
# 359   81132442              Love, Surreal and Odd
# 394   81132441                 Bygones Be Bygones
# 419   81158574                    Brother in Love
# 422   81132440                  Kids on the Block
# 522   81132443                           Deliha 2
# 567   81132439                     Travel Mates 2
# 603   81132438                      Locked on You
# 1424  81076251                         Money Trap
# 1473  81043542                Dabbe 6: The Return
# 1502  81043540                Dabbe 5: Zehr-i Cin
# 1503  81043541              Dabbe: The Possession
# 1841  81043345                       Among Family
# 1853  81043346                    My Travel Buddy
# 1866  81043343            You're Everything To Me
# 3370  80231066                     Babam ve Oğlum
# 3439  80231064              Ali Baba ve 7 Cüceler
# 3440  80227118              Aşk Tesadüfleri Sever
# ...

# %%
df_yeni['Dakika'].min()
# Out:
# '100'

# %%
df_yeni['Dakika'].max()
# Out:
# '99'

# %%
df_yeni['Dakika'] = df_yeni['Dakika'].astype(float)
# Out:
# /Users/hadi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_yeni['Dakika'].min()
# Out:
# 95.0

# %%
df_yeni['Dakika'].max()
# Out:
# 153.0

# %%
df_yeni['Dakika'].mean()
# Out:
# 108.78181818181818

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df_yeni['Dakika'].plot(kind='hist',bins=100)
plt.xlabel='Turk filmlerinin sureleri'
plt.show()

# %%
df_yeni[     df_yeni['Dakika']==153.0     ]
# Out:
#        show_id                title         director  \
# 1473  81043542  Dabbe 6: The Return  Hasan Karacadağ
#
#                                                    cast country  \
# 1473  Sema Şimşek, Nilay Gök, Volkan Ünal, Fehmi Kar...  Turkey
#
#           date_added  release_year rating duration  \
# 1473  April 17, 2019          2015  TV-MA  153 min
#
#                                 listed_in  \
# 1473  Horror Movies, International Movies
#
#                                             description   type  Dakika  min
# 1473  A cardiologist tries to pinpoint the cause of ...  Movie   153.0  min

# %%
df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %%
df[df['listed_in'].str.contains("Comedy")]
# Out:
#        show_id                                              title  \
# 18    81161538                                    Lugar de Mulher
# 28    81062293                        Mike Birbiglia: The New One
# 32    81140259                                          Zona Rosa
# 50    70091304  Mike Birbiglia: What I Should Have Said Was No...
# 96    81073633                         Iliza Shlesinger: Unveiled
# ...        ...                                                ...
# 5803  70290568                          Aziz Ansari: Buried Alive
# 5804  70293417                       Russell Peters vs. the World
# 5805  70280748                          Russell Peters: Notorious
# 5807  70278877                        Iliza Shlesinger: War Paint
# 5835  70157452                                    Dinner for Five
#
#                            director  \
# 18                              NaN
# 28                     Seth Barrish
# 32                              NaN
# ...

# %%
df_yeni[df_yeni['listed_in'].str.contains("Comedy")]
# Out:
# Empty DataFrame
# Columns: [show_id, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, type, Dakika, min]
# Index: []

# %%
df_yeni[df_yeni['listed_in'].str.contains("Comedies")]
# Out:
#        show_id                              title  \
# 359   81132442              Love, Surreal and Odd
# 394   81132441                 Bygones Be Bygones
# 419   81158574                    Brother in Love
# 422   81132440                  Kids on the Block
# 522   81132443                           Deliha 2
# 567   81132439                     Travel Mates 2
# 603   81132438                      Locked on You
# 1424  81076251                         Money Trap
# 1841  81043345                       Among Family
# 1853  81043346                    My Travel Buddy
# 1866  81043343            You're Everything To Me
# 3439  80231064              Ali Baba ve 7 Cüceler
# 3443  80227116                            Görümce
# 3444  80227119                      Hadi İnşallah
# 3446  80227114                        Küçük Esnaf
# 3448  80038443                     Organize Isler
# 3449  80231065                        Pek Yakında
# 4991  80134515                 Bana Masal Anlatma
# ...

# %%
df['Dakika'], df['min'] = df['duration'].str.split(' ', 1).str

# %%
df['Dakika'] = df['Dakika'].astype(float)

# %%
df_grup = df.groupby('country')

# %%
df_grup['Dakika'].min()
# Out:
# country
# Argentina                                                1.0
# Argentina, Brazil, France, Poland, Germany, Denmark     96.0
# Argentina, Chile                                        78.0
# Argentina, Chile, Peru                                 100.0
# Argentina, France                                       87.0
#                                                        ...
# Uruguay, Spain, Mexico                                  74.0
# Venezuela                                              119.0
# Venezuela, Colombia                                     82.0
# Vietnam                                                 92.0
# West Germany                                           150.0
# Name: Dakika, Length: 527, dtype: float64

# %%
df_grup['Dakika'].max()
# Out:
# country
# Argentina                                              115.0
# Argentina, Brazil, France, Poland, Germany, Denmark     96.0
# Argentina, Chile                                        78.0
# Argentina, Chile, Peru                                 100.0
# Argentina, France                                       87.0
#                                                        ...
# Uruguay, Spain, Mexico                                  74.0
# Venezuela                                              119.0
# Venezuela, Colombia                                     82.0
# Vietnam                                                116.0
# West Germany                                           150.0
# Name: Dakika, Length: 527, dtype: float64

# %%
df_grup['Dakika'].describe()
# Out:
#                                                     count        mean  \
# country
# Argentina                                            38.0   57.236842
# Argentina, Brazil, France, Poland, Germany, Den...    1.0   96.000000
# Argentina, Chile                                      1.0   78.000000
# Argentina, Chile, Peru                                1.0  100.000000
# Argentina, France                                     1.0   87.000000
# ...                                                   ...         ...
# Uruguay, Spain, Mexico                                1.0   74.000000
# Venezuela                                             1.0  119.000000
# Venezuela, Colombia                                   1.0   82.000000
# Vietnam                                               4.0  104.250000
# West Germany                                          1.0  150.000000
#
#                                                           std    min     25%  \
# country
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df_grup['Dakika'].mean().plot(kind='hist',bins=100)
plt.xlabel='Ulkelerin Ortalama sureleri'
plt.show()

# %%
df_temiz=df[   df['Dakika']>5     ]
df_temiz
df_temiz = df_temiz.groupby('country')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df_temiz['Dakika'].mean().plot(kind='hist',bins=100)
plt.xlabel='Ulkelerin Ortalama sureleri'
plt.show()
