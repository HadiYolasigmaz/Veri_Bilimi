# %%
## artık elimizde 2 kütüphane var olacak numpy ve pandas
import numpy as np 
import pandas as pd
## Otomobil Fiyatlarını inceleyelim.
df = pd.read_csv('OtomobilFiyatlari.csv')
df.head(3)
# Out:
#         marka      model                          donanim  motor   yakit  \
# 0  Alfa Romeo         4C                          1.8 TCT   1800  Benzin
# 1  Alfa Romeo  4C Spider                          1.8 TCT   1800  Benzin
# 2  Alfa Romeo     Giulia  2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
#
#       vites     fiyat                     websitesi  Unnamed: 8  Unnamed: 9  \
# 0  Otomatik  580000.0  http://www.alfaromeo.com.tr/         NaN         NaN
# 1  Otomatik  620000.0  http://www.alfaromeo.com.tr/         NaN         NaN
# 2  Otomatik  320000.0  http://www.alfaromeo.com.tr/         1.0         NaN
#
#    Unnamed: 10
# 0          1.0
# 1          NaN
# 2          NaN

# %%
df
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
df.count()
# Out:
# marka          1666
# model          1666
# donanim        1666
# motor          1666
# yakit           573
# vites           573
# fiyat           573
# websitesi       573
# Unnamed: 8        1
# Unnamed: 9        0
# Unnamed: 10       1
# dtype: int64

# %%
## data temizlik yapalım önce
df.drop(['Unnamed: 8'], axis=1)
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
## yada
df.drop(columns=['Unnamed: 9', 'Unnamed: 10'])
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
##index numarasına göre silme tabiki satır bazlı silme
df.drop([0, 1])
# Out:
#            marka      model  \
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# 5     Alfa Romeo  Giulietta
# 6     Alfa Romeo  Giulietta
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# 5                    1.4 TB MULTIAIR SUPER BENZİNLİ TCT   1400  Benzin
# 6                    1.6 JTD 120hp PROGRESSION DİZEL MT   1600   Dizel
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
df.drop(index=2, columns='yakit')
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# 5     Alfa Romeo  Giulietta
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor     vites  \
# 0                                               1.8 TCT   1800  Otomatik
# 1                                               1.8 TCT   1800  Otomatik
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Otomatik
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Otomatik
# 5                    1.4 TB MULTIAIR SUPER BENZİNLİ TCT   1400  Otomatik
# ...                                                 ...    ...       ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2  Otomatik
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1666, 11)

# %%
df.ndim
# Out:
# 2

# %%
df.head(3)
# Out:
#         marka      model                          donanim  motor   yakit  \
# 0  Alfa Romeo         4C                          1.8 TCT   1800  Benzin
# 1  Alfa Romeo  4C Spider                          1.8 TCT   1800  Benzin
# 2  Alfa Romeo     Giulia  2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
#
#       vites     fiyat                     websitesi  Unnamed: 8  Unnamed: 9  \
# 0  Otomatik  580000.0  http://www.alfaromeo.com.tr/         NaN         NaN
# 1  Otomatik  620000.0  http://www.alfaromeo.com.tr/         NaN         NaN
# 2  Otomatik  320000.0  http://www.alfaromeo.com.tr/         1.0         NaN
#
#    Unnamed: 10
# 0          1.0
# 1          NaN
# 2          NaN

# %%
df.tail(3)
# Out:
#       marka model                                            donanim  motor  \
# 1663  Volvo  XC90  2.0L 320+87HP T8 Twin Engine AWD 7-koltuk Insc...      2
# 1664  Volvo  XC90  2.0L 320+87HP T8 Twin Engine AWD 7-koltuk Mome...      2
# 1665  Volvo  XC90  2.0L 320+87HP T8 Twin Engine AWD 7-koltuk R-De...      2
#
#        yakit     vites     fiyat                    websitesi  Unnamed: 8  \
# 1663  Hibrit  Otomatik  643030.0  http://www.volvocars.com.tr         NaN
# 1664  Hibrit  Otomatik  614890.0  http://www.volvocars.com.tr         NaN
# 1665  Hibrit  Otomatik  648400.0  http://www.volvocars.com.tr         NaN
#
#       Unnamed: 9  Unnamed: 10
# 1663         NaN          NaN
# 1664         NaN          NaN
# 1665         NaN          NaN

# %%
df.dtypes
# Out:
# marka           object
# model           object
# donanim         object
# motor            int64
# yakit           object
# vites           object
# fiyat          float64
# websitesi       object
# Unnamed: 8     float64
# Unnamed: 9     float64
# Unnamed: 10    float64
# dtype: object

# %%
df.describe()
# Out:
#              motor         fiyat  Unnamed: 8  Unnamed: 9  Unnamed: 10
# count  1666.000000  5.730000e+02         1.0         0.0          1.0
# mean    368.554622  4.370807e+05         1.0         NaN          1.0
# std     833.656244  3.458123e+05         NaN         NaN          NaN
# min       0.000000  4.500000e+04         1.0         NaN          1.0
# 25%       1.000000  2.055000e+05         1.0         NaN          1.0
# 50%       1.000000  3.437600e+05         1.0         NaN          1.0
# 75%       2.000000  5.105300e+05         1.0         NaN          1.0
# max    6300.000000  2.275100e+06         1.0         NaN          1.0

# %%
## Datamızdan kolon seçme işlemi yapalım
## Yöntem 1
df.marka.head(3)
# Out:
# 0    Alfa Romeo
# 1    Alfa Romeo
# 2    Alfa Romeo
# Name: marka, dtype: object

# %%
## 2. Yöntem indexler üzerinden bu yüzden iloc kullanacağız.
df.iloc[:,2].head(3)
# Out:
# 0                            1.8 TCT
# 1                            1.8 TCT
# 2    2.0 200hp SUPER RWD BENZİNLİ AT
# Name: donanim, dtype: object

# %%
## 3.Yöntem
df['marka'].head(3)
# Out:
# 0    Alfa Romeo
# 1    Alfa Romeo
# 2    Alfa Romeo
# Name: marka, dtype: object

# %%
df['motor'].sum()
# Out:
# 614012

# %%
df['motor'].mean()
# Out:
# 368.5546218487395

# %%
df['motor'].median()
# Out:
# 1.0

# %%
df['motor'].nunique()
# Out:
# 19

# %%
df['motor'].max()
# Out:
# 6300

# %%
df['motor'].min()
# Out:
# 0

# %%
df
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
## sütun seçmek istediğimizde
df[['marka','model','motor']]
# Out:
#            marka      model  motor
# 0     Alfa Romeo         4C   1800
# 1     Alfa Romeo  4C Spider   1800
# 2     Alfa Romeo     Giulia   2000
# 3     Alfa Romeo     Giulia   2000
# 4     Alfa Romeo     Giulia   2900
# ...          ...        ...    ...
# 1661       Volvo       XC90      2
# 1662       Volvo       XC90      2
# 1663       Volvo       XC90      2
# 1664       Volvo       XC90      2
# 1665       Volvo       XC90      2
#
# [1666 rows x 3 columns]

# %%
df.iloc[: ,[1,2,4]]
# Out:
#           model                                            donanim   yakit
# 0            4C                                            1.8 TCT  Benzin
# 1     4C Spider                                            1.8 TCT  Benzin
# 2        Giulia                    2.0 200hp SUPER RWD BENZİNLİ AT  Benzin
# 3        Giulia                   2.0 280hp VELOCE AWD BENZİNLİ AT  Benzin
# 4        Giulia                       2.9 510hp QV RWD BENZİNLİ AT  Benzin
# ...         ...                                                ...     ...
# 1661       XC90                2.0L 235HP D5 AWD 7-koltuk R-Design   Dizel
# 1662       XC90  2.0L 320+87HP T8 Twin Engine AWD 4-koltuk Exce...  Hibrit
# 1663       XC90  2.0L 320+87HP T8 Twin Engine AWD 7-koltuk Insc...  Hibrit
# 1664       XC90  2.0L 320+87HP T8 Twin Engine AWD 7-koltuk Mome...  Hibrit
# 1665       XC90  2.0L 320+87HP T8 Twin Engine AWD 7-koltuk R-De...  Hibrit
#
# [1666 rows x 3 columns]

# %%
## satır seçmek istediğimizde
df.iloc[0:100 ,[1,2,4]]
# Out:
#          model                           donanim   yakit
# 0           4C                           1.8 TCT  Benzin
# 1    4C Spider                           1.8 TCT  Benzin
# 2       Giulia   2.0 200hp SUPER RWD BENZİNLİ AT  Benzin
# 3       Giulia  2.0 280hp VELOCE AWD BENZİNLİ AT  Benzin
# 4       Giulia      2.9 510hp QV RWD BENZİNLİ AT  Benzin
# ..         ...                               ...     ...
# 95          A6  3.0 TDI 272 hp quattro S tronic    Dizel
# 96          A6  3.0 TDI 320 hp quattro tiptronic   Dizel
# 97  A6 Allroad   3.0 TDI 272 hp quattro S tronic   Dizel
# 98  A6 Allroad  3.0 TDI 320 hp quattro tiptronic   Dizel
# 99    A6 Avant   2.0 TDI 190 hp quattro S tronic   Dizel
#
# [100 rows x 3 columns]

# %%
## eğer indekslenmiş bir dataframimiz var ise
df.loc[97 ,:]
# Out:
# marka                                     Audi
# model                               A6 Allroad
# donanim        3.0 TDI 272 hp quattro S tronic
# motor                                     3000
# yakit                                    Dizel
# vites                                 Otomatik
# fiyat                                   571639
# websitesi              http://www.audi.com.tr/
# Unnamed: 8                                 NaN
# Unnamed: 9                                 NaN
# Unnamed: 10                                NaN
# Name: 97, dtype: object

# %%
df[       df['marka']=='Audi'     ]
# Out:
#     marka           model                                        donanim  \
# 10   Audi    A1 Sportback                1.0 TFSI 95 hp Dynamic S tronic
# 11   Audi    A1 Sportback                  1.0 TFSI 95 hp Sport S tronic
# 12   Audi    A1 Sportback               1.4 TFSI 125 hp Dynamic S tronic
# 13   Audi    A1 Sportback                1.4 TFSI 125 hp Sport S tronic
# 14   Audi    A1 Sportback               1.6 TDI 116 hp Dynamic S tronic
# ..    ...             ...                                            ...
# 127  Audi  RS 7 Sportback  4.0 TFSI 605 hp performance quattro tiptronic
# 128  Audi              S8              4.0 TFSI 520 hp quattro tiptronic
# 129  Audi              S8         4.0 TFSI 605 hp plus quattro tiptronic
# 130  Audi        TT Coupe               2.0 TFSI 230 hp quattro S tronic
# 131  Audi       TTS Coupe               2.0 TFSI 310 hp quattro S tronic
#
#      motor   yakit     vites      fiyat                websitesi  Unnamed: 8  \
# ...

# %%
df['marka']=='Audi'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1661    False
# 1662    False
# 1663    False
# 1664    False
# 1665    False
# Name: marka, Length: 1666, dtype: bool

# %%
df.drop(['Unnamed: 8'], axis=1, inplace=True)

# %%
df
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
## kolon adı değiştirme işlemi
df = df.rename(columns={"Unnamed: 9": "silinecek"})

# %%
# yada
df.rename(columns={"Unnamed: 10": "Bu da silinecek"}, inplace=True)

# %%
df
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
df.rename( columns={ "silinecek": "sil1",   "Bu da silinecek": "sil2" },  inplace=True)

# %%
df
# Out:
#            marka      model  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 donanim  motor   yakit  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
# yada tüm baslıkları büyük harfe öevirelim
df.rename(columns=str.upper)
# Out:
#            MARKA      MODEL  \
# 0     Alfa Romeo         4C
# 1     Alfa Romeo  4C Spider
# 2     Alfa Romeo     Giulia
# 3     Alfa Romeo     Giulia
# 4     Alfa Romeo     Giulia
# ...          ...        ...
# 1661       Volvo       XC90
# 1662       Volvo       XC90
# 1663       Volvo       XC90
# 1664       Volvo       XC90
# 1665       Volvo       XC90
#
#                                                 DONANIM  MOTOR   YAKIT  \
# 0                                               1.8 TCT   1800  Benzin
# 1                                               1.8 TCT   1800  Benzin
# 2                       2.0 200hp SUPER RWD BENZİNLİ AT   2000  Benzin
# 3                      2.0 280hp VELOCE AWD BENZİNLİ AT   2000  Benzin
# 4                          2.9 510hp QV RWD BENZİNLİ AT   2900  Benzin
# ...                                                 ...    ...     ...
# 1661                2.0L 235HP D5 AWD 7-koltuk R-Design      2   Dizel
# ...

# %%
##Dosyamızı Saklayalım
df.to_csv("panda_csv_dosya.csv", index=False, encoding='utf8')
df.to_csv("panda_csv_dosya_indeksli.csv", index=True, encoding='utf8')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df['fiyat'].plot(kind='hist',bins=100)
plt.xlabel='Otomobil Fiyatları'
plt.show()

# %%
df_marka_model = pd.read_csv('Audi Marka Model.csv')
df_marka_model.head()
# Out:
#         marka      model                             donanim
# 0  Alfa Romeo         4C                             1.8 TCT
# 1  Alfa Romeo  4C Spider                             1.8 TCT
# 2  Alfa Romeo     Giulia   2.0 200hp SUPER RWD BENZƒ∞NLƒ∞ AT
# 3  Alfa Romeo     Giulia  2.0 280hp VELOCE AWD BENZƒ∞NLƒ∞ AT
# 4  Alfa Romeo     Giulia      2.9 510hp QV RWD BENZƒ∞NLƒ∞ AT

# %%
## dosya birleştirme örnekleri
df_motor = pd.read_csv('Audi motor.csv')
df_motor.head()
# Out:
#                               donanim  motor
# 0                             1.8 TCT   1800
# 1                             1.8 TCT   1800
# 2   2.0 200hp SUPER RWD BENZƒ∞NLƒ∞ AT   2000
# 3  2.0 280hp VELOCE AWD BENZƒ∞NLƒ∞ AT   2000
# 4      2.9 510hp QV RWD BENZƒ∞NLƒ∞ AT   2900

# %%
df_Yakit_Vites = pd.read_csv('Audi_Yakit_Vites.csv')
df_Yakit_Vites.head()
# Out:
#                               donanim   yakit     vites
# 0                             1.8 TCT  Benzin  Otomatik
# 1                             1.8 TCT  Benzin  Otomatik
# 2   2.0 200hp SUPER RWD BENZƒ∞NLƒ∞ AT  Benzin  Otomatik
# 3  2.0 280hp VELOCE AWD BENZƒ∞NLƒ∞ AT  Benzin  Otomatik
# 4      2.9 510hp QV RWD BENZƒ∞NLƒ∞ AT  Benzin  Otomatik

# %%
df_fiyat = pd.read_csv('Audi_Fiyat.csv')
df_fiyat.head()
# Out:
#                               donanim     fiyat
# 0                             1.8 TCT  580000.0
# 1                             1.8 TCT  620000.0
# 2   2.0 200hp SUPER RWD BENZƒ∞NLƒ∞ AT  320000.0
# 3  2.0 280hp VELOCE AWD BENZƒ∞NLƒ∞ AT  380000.0
# 4      2.9 510hp QV RWD BENZƒ∞NLƒ∞ AT  780000.0

# %%
df1 = pd.merge(df_marka_model,
                 df_motor[['donanim', 'motor']],
                 on='donanim')
df1.head()
# Out:
#         marka      model                            donanim  motor
# 0  Alfa Romeo         4C                            1.8 TCT   1800
# 1  Alfa Romeo         4C                            1.8 TCT   1800
# 2  Alfa Romeo  4C Spider                            1.8 TCT   1800
# 3  Alfa Romeo  4C Spider                            1.8 TCT   1800
# 4  Alfa Romeo     Giulia  2.0 200hp SUPER RWD BENZƒ∞NLƒ∞ AT   2000

# %%
df_marka_model['donanim'].isin(df_motor['donanim']).value_counts()
# Out:
# True    1666
# Name: donanim, dtype: int64
